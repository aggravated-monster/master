# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_B2_13 = pd.read_csv("../results/20240516-19.46.28_B2-long/logs/explain/20240516-19.46.28_B2-long_episodes.csv", header=None)
# add column names
df_B2_13.columns =['timestamp', 'name', 'seed', 'total_steps', 'episode', 'episode_steps', 'reward', 'distance', 'velocity', 'game_time', 'game_score', 'flag', 'loss', 'epsilon', 'dataset']
df_B2_13['ewm_reward'] = df_B2_13['reward'].ewm(alpha=0.01).mean()
df_B2_13['ewm_wins'] = df_B2_13['flag'].ewm(alpha=0.01).mean()
df_B2_13.head(5)
# Out:
#                  timestamp           name  seed  total_steps  episode  \
# 0  2024-05-16 19:46:29.997  game_episodes    13          102        1
# 1  2024-05-16 19:46:39.628  game_episodes    13         1135        2
# 2  2024-05-16 19:46:46.028  game_episodes    13         1851        3
# 3  2024-05-16 19:46:53.453  game_episodes    13         2633        4
# 4  2024-05-16 19:46:54.214  game_episodes    13         2715        5
#
#    episode_steps  reward  distance   velocity  game_time  game_score   flag  \
# 0            102   598.0       675  33.750000        380           0  False
# 1           1033   637.0       898   4.359223        194         200  False
# 2            716  1233.0      1434  10.027972        257         900  False
# 3            782   936.0      1150   7.371795        244         600  False
# 4             82   612.0       686  42.875000        384           0  False
#
#        loss   epsilon  dataset  ewm_reward  ewm_wins
# 0  3.954245  0.999661  B2-long  598.000000       0.0
# 1  0.394172  0.995642  B2-long  617.597990       0.0
# 2  1.040487  0.992865  B2-long  824.797078       0.0
# 3  0.288787  0.989842  B2-long  853.018312       0.0
# 4  0.584212  0.989525  B2-long  803.840887       0.0

# %%
df_B2_42 = pd.read_csv("../results/20240602-22.32.40_B2-42/explain/20240602-22.32.40_B2-long_episodes.csv", header=None)
# add column names
df_B2_42.columns =['timestamp', 'name', 'seed', 'total_steps', 'episode', 'episode_steps', 'reward', 'distance', 'velocity', 'game_time', 'game_score', 'flag', 'loss', 'epsilon', 'dataset']
df_B2_42['ewm_reward'] = df_B2_42['reward'].ewm(alpha=0.01).mean()
df_B2_42['ewm_wins'] = df_B2_42['flag'].ewm(alpha=0.01).mean()
df_B2_42.head(5)
# Out:
#                  timestamp           name  seed  total_steps  episode  \
# 0  2024-06-02 22:32:46.089  game_episodes    42          455        1
# 1  2024-06-02 22:32:46.384  game_episodes    42          488        2
# 2  2024-06-02 22:32:46.728  game_episodes    42          526        3
# 3  2024-06-02 22:32:47.047  game_episodes    42          562        4
# 4  2024-06-02 22:32:54.787  game_episodes    42         1439        5
#
#    episode_steps  reward  distance   velocity  game_time  game_score   flag  \
# 0            455   711.0       859   9.544444        310         200  False
# 1             33   243.0       307  51.166667        394         200  False
# 2             38   229.0       293  41.857143        393         200  False
# 3             36   245.0       309  44.142857        393           0  False
# 4            877   897.0      1127   6.440000        225         300  False
#
#        loss   epsilon dataset  ewm_reward  ewm_wins
# 0  1.564319  0.998285   B2-42  711.000000       0.0
# 1  2.069469  0.998157   B2-42  475.824121       0.0
# 2  1.060860  0.998009   B2-42  392.721154       0.0
# 3  1.705705  0.997869   B2-42  355.232272       0.0
# 4  0.413309  0.994462   B2-42  465.774667       0.0

# %%
concatenated = pd.concat([df_B2_13, df_B2_42])

# %%
sns.lineplot(x='episode', y='ewm_reward', data=concatenated, hue='seed', palette=sns.color_palette('Set2', n_colors=2)).set(xlabel="Episodes trained", ylabel="EWM rewards (alpha=0.01)")
plt.savefig("./training_B2_rewards_seeding.png")

# %%
sns.lineplot(x='episode', y='ewm_wins', data=concatenated, hue='seed', palette=sns.color_palette('Set2', n_colors=2)).set(xlabel="Episodes trained", ylabel="EWM wins (alpha=0.01)")
plt.savefig("./training_B2_wins_seeding.png")

# %%
df_T2_13 = pd.read_csv("../results/10000eps/20240513-18.01.40_T2-ni/logs/explain/20240513-18.01.40_T2-ni_episodes.csv", header=None)
# add column names
df_T2_13.columns =['timestamp', 'name', 'seed', 'total_steps', 'episode', 'episode_steps', 'reward', 'distance', 'velocity', 'game_time', 'game_score', 'flag', 'loss', 'epsilon', 'dataset']
df_T2_13['ewm_reward'] = df_T2_13['reward'].ewm(alpha=0.01).mean()
df_T2_13['ewm_wins'] = df_T2_13['flag'].ewm(alpha=0.01).mean()
df_T2_13.head(5)
# Out:
#                  timestamp           name  seed  total_steps  episode  \
# 0  2024-05-13 18:02:08.648  game_episodes    13         1064        1
# 1  2024-05-13 18:02:09.624  game_episodes    13         1099        2
# 2  2024-05-13 18:02:13.541  game_episodes    13         1248        3
# 3  2024-05-13 18:02:50.222  game_episodes    13         2571        4
# 4  2024-05-13 18:03:25.476  game_episodes    13         3680        5
#
#    episode_steps  reward  distance   velocity  game_time  game_score   flag  \
# 0           1064   631.0       898   4.235849        188         100  False
# 1             35   234.0       298  49.666667        394           0  False
# 2            149   638.0       722  24.896552        371           0  False
# 3           1323  1350.0      1671   6.329545        136         400  False
# 4           1109  1242.0      1520   6.877828        179         400  False
#
#        loss   epsilon dataset  ewm_reward  ewm_wins
# 0  0.556482  0.995917   T2_ni  631.000000       0.0
# 1  0.635247  0.995781   T2_ni  431.502513       0.0
# 2  0.590840  0.995203   T2_ni  501.027945       0.0
# 3  0.271077  0.990081   T2_ni  716.481267       0.0
# 4  0.427263  0.985808   T2_ni  823.708214       0.0

# %%
df_T2_42 = pd.read_csv("../results/10000eps/20240603-18.45.22_T2_ni_42/logs/explain/20240603-18.45.22_T2_ni_42_episodes.csv", header=None)
# add column names
df_T2_42.columns =['timestamp', 'name', 'seed', 'total_steps', 'episode', 'episode_steps', 'reward', 'distance', 'velocity', 'game_time', 'game_score', 'flag', 'loss', 'epsilon', 'dataset']
df_T2_42['ewm_reward'] = df_T2_42['reward'].ewm(alpha=0.01).mean()
df_T2_42['ewm_wins'] = df_T2_42['flag'].ewm(alpha=0.01).mean()
df_T2_42.head(5)
# Out:
#                  timestamp           name  seed  total_steps  episode  \
# 0  2024-06-03 18:45:45.594  game_episodes    42          862        1
# 1  2024-06-03 18:46:04.539  game_episodes    42         1637        2
# 2  2024-06-03 18:46:05.301  game_episodes    42         1666        3
# 3  2024-06-03 18:46:06.343  game_episodes    42         1704        4
# 4  2024-06-03 18:46:07.562  game_episodes    42         1748        5
#
#    episode_steps  reward  distance   velocity  game_time  game_score   flag  \
# 0            862  1545.0      1773  10.308140        228         300  False
# 1            775  1310.0      1520   9.870130        246         300  False
# 2             29   247.0       310  62.000000        395           0  False
# 3             38   236.0       300  42.857143        393           0  False
# 4             44   238.0       304  38.000000        392           0  False
#
#        loss   epsilon   dataset   ewm_reward  ewm_wins
# 0  0.726256  0.996702  T2_ni_42  1545.000000       0.0
# 1  0.824351  0.993694  T2_ni_42  1426.909548       0.0
# 2  0.643465  0.993582  T2_ni_42  1029.646982       0.0
# 3  0.800112  0.993435  T2_ni_42   828.234134       0.0
# 4  0.639407  0.993264  T2_ni_42   707.802644       0.0

# %%
concatenated2 = pd.concat([df_T2_13, df_T2_42])

# %%
sns.lineplot(x='episode', y='ewm_reward', data=concatenated2, hue='seed', palette=sns.color_palette('Set2', n_colors=2)).set(xlabel="Episodes trained", ylabel="EWM rewards (alpha=0.01)")
plt.savefig("./training_T2_rewards_seeding.png")

# %%
sns.lineplot(x='episode', y='ewm_wins', data=concatenated2, hue='seed', palette=sns.color_palette('Set2', n_colors=2)).set(xlabel="Episodes trained", ylabel="EWM wins (alpha=0.01)")
plt.savefig("./training_T2_wins_seeding.png")
